# %% [markdown]
# <a href="https://colab.research.google.com/github/himanshu230998/CS504-project/blob/main/Chaotic_system_double_pendulum_return_seq_False_sequence_length(100)_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import
from numpy import sin, cos
import numpy as np
import matplotlib.pyplot as plt
import scipy.integrate as integrate
import pickle
from itertools import *

import csv

import matplotlib.animation as animation
import random
import matplotlib.patches as mpatches
from statsmodels.tsa.arima_model import ARMA
from sklearn.metrics import r2_score
import pandas as pd
import tensorflow as tf


from pandas import read_csv
import math
from keras.models import Sequential
from keras.layers import Dense, Dropout, LeakyReLU
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
G = 9.8  # acceleration due to gravity, in m/s^2
L1 = 1.0  # length of pendulum 1 in m
L2 = 1.0  # length of pendulum 2 in m
M1 = 1.0  # mass of pendulum 1 in kg
M2 = 2.0  # mass of pendulum 2 in kg

# derivs(state,t) returns array of 4 number [Z1, Z1_dot, Z2, Z2_dot]
def derivs(state, t):
    
    dydx = np.zeros_like(state)
    dydx[0] = state[1]

    del_ = state[2] - state[0]
    den1 = (M1 + M2)*L1 - M2*L1*cos(del_)*cos(del_) #del1=L1*(M1+M2*sin(del)*sin(del))
    dydx[1] = (M2*L1*state[1]*state[1]*sin(del_)*cos(del_) +
               M2*G*sin(state[2])*cos(del_) +
               M2*L2*state[3]*state[3]*sin(del_) -
               (M1 + M2)*G*sin(state[0]))/den1

    dydx[2] = state[3]

    den2 = (L2/L1)*den1
    dydx[3] = (-M2*L2*state[3]*state[3]*sin(del_)*cos(del_) +
               (M1 + M2)*G*sin(state[0])*cos(del_) -
               (M1 + M2)*L1*state[1]*state[1]*sin(del_) -
               (M1 + M2)*G*sin(state[2]))/den2

    return dydx

 
dt = 0.01
t = np.arange(0.0, 100 , dt)       #len(t)=9999
arr=[]
time=[]
state = np.radians([75, 0, 50, 0])
y = integrate.odeint(derivs, state, t)   #len(y)=9999
x1 = 1 * sin(y[:, 0])
y1 = 1 * cos(y[:, 0])
x2 = 1 * sin(y[:, 2]) + x1
y2 = 1 * cos(y[:, 2]) + y1
for i in range(len(x1)):
    # all=[x1[i],y1[i],x2[i],y2[i]]
    arr.append(np.array([x1[i],y1[i],x2[i],y2[i]]))

# %%
dt = 0.01
t = np.arange(0.0, 100 , dt)       #len(t)=9999
arr=[]
time=[]
state = np.radians([170, 0.1, 150, 0.1])
y = integrate.odeint(derivs, state, t)  
z1 = y[:,0]
z1_dot = y[:,1]
z2 = y[:,2]
z2_dot = y[:,3]

# %%
plt.figure()
plt.title('Simulated Trajectory of Double Pendulum ((X1,Y1) and (X2,Y2))')
plt.xlabel('X-axis', fontsize=12)
plt.ylabel('Y-axis', fontsize=12)
plt.plot(L1*sin(z1), -L1*cos(z1),label='First Pendulum (X1,Y1)' ,color="RED")
plt.plot(L2*sin(z2)+L1*sin(z1), -L2*cos(z2)-L2*cos(z1),label='Second Pendulum (X2,Y2)' ,color="BLUE")
plt.legend()
# plt.plot(z2_dot+sin(data[:,3][8100:10000]),-cos(data[:,1][8100:10000])-cos(data[:,3][8100:10000]),color="blue")

# %%
plt.figure()
plt.title('Simulated Angular Velocity of Double Pendulum ((T,$\\dot{\\theta1}$) and (T,$\\dot{\\theta2}$))')
plt.xlabel('Time', fontsize=12)
plt.ylabel('Angular Velocity', fontsize=12)
plt.plot(t,z1_dot,label='Angular Velocity of First Pendulum' ,color="RED")
plt.plot(t,z2_dot+z1_dot,label='Angular Velocity of Double Pendulum' ,color="blue")
plt.legend()

# %%
import csv
with open('/content/drive/MyDrive/CS504 project/Hamiltonian-chaotic.csv', 'w', newline='') as file:
    fieldnames = ['Time', 'Z1','Z1_dot','Z2','Z2_dot']
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    writer.writerow({'Time': "Time", 'Z1':"Z1",'Z1_dot': "Z1_dot",'Z2':"Z2",'Z2_dot':"Z2_dot"})
    for i in range(0,len(t)):
        writer.writerow({'Time': t[i], 'Z1':z1[i],'Z1_dot': z1_dot[i],'Z2':z2[i],'Z2_dot':z2_dot[i]})

# %% [markdown]
# ##Data process

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras.preprocessing.sequence import TimeseriesGenerator
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import tensorflow as tf

# %%
df = pd.read_csv('/content/drive/MyDrive/CS504 project/Hamiltonian-chaotic.csv')

# %%
df
# Out:
#        Time        Z1    Z1_dot         Z2    Z2_dot
# 0      0.00  2.967060  0.001745   2.617994  0.001745
# 1      0.01  2.967243  0.035008   2.617610 -0.078519
# 2      0.02  2.967760  0.068302   2.616423 -0.158857
# 3      0.03  2.968610  0.101651   2.614432 -0.239340
# 4      0.04  2.969793  0.135076   2.611636 -0.320034
# ...     ...       ...       ...        ...       ...
# 9995  99.95 -3.233267 -6.395431 -24.636787 -4.391167
# 9996  99.96 -3.297035 -6.357806 -24.679630 -4.175931
# 9997  99.97 -3.360417 -6.318187 -24.720275 -3.951438
# 9998  99.98 -3.423393 -6.276744 -24.758629 -3.717895
# 9999  99.99 -3.485947 -6.233771 -24.794604 -3.475657
#
# [10000 rows x 5 columns]

# %%
df_input=df[['Time', 'Z1','Z1_dot','Z2','Z2_dot']]
df_input
# Out:
#        Time        Z1    Z1_dot         Z2    Z2_dot
# 0      0.00  2.967060  0.001745   2.617994  0.001745
# 1      0.01  2.967243  0.035008   2.617610 -0.078519
# 2      0.02  2.967760  0.068302   2.616423 -0.158857
# 3      0.03  2.968610  0.101651   2.614432 -0.239340
# 4      0.04  2.969793  0.135076   2.611636 -0.320034
# ...     ...       ...       ...        ...       ...
# 9995  99.95 -3.233267 -6.395431 -24.636787 -4.391167
# 9996  99.96 -3.297035 -6.357806 -24.679630 -4.175931
# 9997  99.97 -3.360417 -6.318187 -24.720275 -3.951438
# 9998  99.98 -3.423393 -6.276744 -24.758629 -3.717895
# 9999  99.99 -3.485947 -6.233771 -24.794604 -3.475657
#
# [10000 rows x 5 columns]

# %%
with open('/content/drive/MyDrive/CS504 project/Hamiltonian-chaotic.csv', 'r') as f:
    reader = csv.reader(f, delimiter=',')
    headers = next(reader)
    data = np.array(list(reader)).astype(float)
print(headers)
print(data.shape)
print(data)
# Out:
# ['Time', 'Z1', 'Z1_dot', 'Z2', 'Z2_dot']
# (10000, 5)
# [[ 0.00000000e+00  2.96705973e+00  1.74532925e-03  2.61799388e+00
#    1.74532925e-03]
#  [ 1.00000000e-02  2.96724348e+00  3.50081703e-02  2.61761004e+00
#   -7.85185119e-02]
#  [ 2.00000000e-02  2.96775999e+00  6.83017460e-02  2.61642326e+00
#   -1.58856876e-01]
#  ...
#  [ 9.99700000e+01 -3.36041692e+00 -6.31818724e+00 -2.47202748e+01
#   -3.95143793e+00]
#  [ 9.99800000e+01 -3.42339299e+00 -6.27674419e+00 -2.47586289e+01
#   -3.71789490e+00]
#  [ 9.99900000e+01 -3.48594668e+00 -6.23377087e+00 -2.47946037e+01
#   -3.47565711e+00]]

# %%
data[:,0][8001:10001]
# Out:
# array([80.01, 80.02, 80.03, ..., 99.97, 99.98, 99.99])

# %%
data[:,1][8001:10001]
# Out:
# array([-44.59696826, -44.58462784, -44.57576825, ...,  -3.36041692,
#         -3.42339299,  -3.48594668])

# %%
df_input.describe()
# Out:
#                Time            Z1        Z1_dot            Z2        Z2_dot
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      49.995000    -26.347221     -0.064842    -52.425674     -0.274297
# std       28.868957     18.066836      4.950718     27.578978      5.890599
# min        0.000000    -52.925920    -13.696809    -96.635037    -16.731387
# 25%       24.997500    -43.198019     -3.909710    -78.347136     -4.965248
# 50%       49.995000    -27.538649      0.159137    -57.107121     -0.562307
# 75%       74.992500    -11.023707      3.673941    -31.178333      4.487751
# max       99.990000      8.968844     13.752907      3.143048     16.698491

# %%
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(df_input)

# %%
data_scaled
# Out:
# array([[0.00000000e+00, 9.03032436e-01, 4.99041739e-01, 9.94737779e-01,
#         5.00544222e-01],
#        [1.00010001e-04, 9.03035404e-01, 5.00253513e-01, 9.94733932e-01,
#         4.98143261e-01],
#        [2.00020002e-04, 9.03043749e-01, 5.01466406e-01, 9.94722038e-01,
#         4.95740071e-01],
#        ...,
#        [9.99799980e-01, 8.00802841e-01, 2.68805018e-01, 7.20747067e-01,
#         3.82291227e-01],
#        [9.99899990e-01, 7.99785371e-01, 2.70314799e-01, 7.20362673e-01,
#         3.89277284e-01],
#        [1.00000000e+00, 7.98774725e-01, 2.71880328e-01, 7.20002125e-01,
#         3.96523430e-01]])

# %%
features=data_scaled
target=data_scaled

# %%
x_train=features[0:8000]
y_train=target[0:8000]
x_test=features[8000:10000]
y_test=target[8000:10000]

# %%
win_length=100
batch_size=1
num_features=5
train_generator = TimeseriesGenerator(x_train, y_train, length=win_length, sampling_rate=1, batch_size=batch_size)
test_generator = TimeseriesGenerator(x_test, y_test, length=win_length, sampling_rate=1, batch_size=batch_size)

# %%
X=np.array(([train_generator[0][0][0,:]]))
Y1=np.array(np.vstack((train_generator[0][1][:,0])))
Y2=np.array(np.vstack((train_generator[0][1][:,1])))
Y3=np.array(np.vstack((train_generator[0][1][:,2])))
Y4=np.array(np.vstack((train_generator[0][1][:,3])))
Y5=np.array(np.vstack((train_generator[0][1][:,4])))

for i in range(1,7900):
    X=np.vstack((X,[train_generator[i][0][0,:]]))
    Y1=np.vstack((Y1,train_generator[i][1][:,0]))
    Y2=np.vstack((Y2,train_generator[i][1][:,1]))
    Y3=np.vstack((Y3,train_generator[i][1][:,2]))
    Y4=np.vstack((Y4,train_generator[i][1][:,3]))
    Y5=np.vstack((Y5,train_generator[i][1][:,4]))

# %%
win_length=100
batch_size=1
num_features=5
title_input = keras.Input(shape= (win_length, num_features), name="title_input") 
title_features = layers.Dense(5)(title_input)

LSTM1 = layers.LSTM(30, input_shape= (win_length, num_features))(title_features)
LSTM2 = layers.LSTM(30, input_shape= (win_length, num_features))(title_features)
LSTM3 = layers.LSTM(30, input_shape= (win_length, num_features))(title_features)
LSTM4 = layers.LSTM(30, input_shape= (win_length, num_features))(title_features)
LSTM5 = layers.LSTM(30, input_shape= (win_length, num_features))(title_features)

out1=layers.Dense(1,name="out1")(LSTM1)
out2=layers.Dense(1,name="out2")(LSTM2)
out3=layers.Dense(1,name="out3")(LSTM3)
out4=layers.Dense(1,name="out4")(LSTM4)
out5=layers.Dense(1,name="out5")(LSTM5)

model = keras.Model(
    inputs=[title_input],
    outputs=[out1, out2,out3,out4,out5],
)

# %%
keras.utils.plot_model(model, show_shapes=True)

# %%
model.compile(loss=tf.losses.MeanSquaredError(),optimizer=tf.optimizers.Adam(),metrics=[tf.metrics.MeanAbsoluteError()])

history = model.fit(    {"title_input": X},
    {"out1": Y1, "out2": Y2, "out3": Y3, "out4": Y4, "out5": Y5,}, 
    epochs=30, validation_batch_size=0.1,
    shuffle=False)
# Out:
# Epoch 1/30
# 247/247 [==============================] - 33s 133ms/step - loss: 0.1253 - out1_loss: 0.0034 - out2_loss: 0.0274 - out3_loss: 0.0314 - out4_loss: 0.0432 - out5_loss: 0.0197 - out1_mean_absolute_error: 0.0470 - out2_mean_absolute_error: 0.1019 - out3_mean_absolute_error: 0.1334 - out4_mean_absolute_error: 0.1036 - out5_mean_absolute_error: 0.1043
# Epoch 2/30
# 247/247 [==============================] - 32s 132ms/step - loss: 0.0437 - out1_loss: 0.0114 - out2_loss: 0.0049 - out3_loss: 0.0082 - out4_loss: 0.0049 - out5_loss: 0.0142 - out1_mean_absolute_error: 0.0462 - out2_mean_absolute_error: 0.0550 - out3_mean_absolute_error: 0.0729 - out4_mean_absolute_error: 0.0568 - out5_mean_absolute_error: 0.0835
# Epoch 3/30
# 247/247 [==============================] - 33s 133ms/step - loss: 0.0293 - out1_loss: 0.0068 - out2_loss: 0.0024 - out3_loss: 0.0089 - out4_loss: 0.0067 - out5_loss: 0.0045 - out1_mean_absolute_error: 0.0437 - out2_mean_absolute_error: 0.0398 - out3_mean_absolute_error: 0.0746 - out4_mean_absolute_error: 0.0649 - out5_mean_absolute_error: 0.0487
# Epoch 4/30
# 247/247 [==============================] - 34s 136ms/step - loss: 0.0293 - out1_loss: 0.0059 - out2_loss: 0.0027 - out3_loss: 0.0096 - out4_loss: 0.0090 - out5_loss: 0.0020 - out1_mean_absolute_error: 0.0527 - out2_mean_absolute_error: 0.0421 - out3_mean_absolute_error: 0.0747 - out4_mean_absolute_error: 0.0733 - out5_mean_absolute_error: 0.0343
# Epoch 5/30
# 247/247 [==============================] - 33s 134ms/step - loss: 0.0274 - out1_loss: 0.0052 - out2_loss: 0.0029 - out3_loss: 0.0074 - out4_loss: 0.0100 - out5_loss: 0.0018 - out1_mean_absolute_error: 0.0565 - out2_mean_absolute_error: 0.0427 - out3_mean_absolute_error: 0.0664 - out4_mean_absolute_error: 0.0761 - out5_mean_absolute_error: 0.0329
# Epoch 6/30
# 247/247 [==============================] - 33s 132ms/step - loss: 0.0249 - out1_loss: 0.0049 - out2_loss: 0.0030 - out3_loss: 0.0053 - out4_loss: 0.0099 - out5_loss: 0.0018 - out1_mean_absolute_error: 0.0571 - out2_mean_absolute_error: 0.0425 - out3_mean_absolute_error: 0.0574 - out4_mean_absolute_error: 0.0754 - out5_mean_absolute_error: 0.0333
# Epoch 7/30
# 247/247 [==============================] - 33s 133ms/step - loss: 0.0231 - out1_loss: 0.0048 - out2_loss: 0.0030 - out3_loss: 0.0040 - out4_loss: 0.0094 - out5_loss: 0.0019 - out1_mean_absolute_error: 0.0569 - out2_mean_absolute_error: 0.0425 - out3_mean_absolute_error: 0.0506 - out4_mean_absolute_error: 0.0735 - out5_mean_absolute_error: 0.0345
# Epoch 8/30
# 247/247 [==============================] - 33s 132ms/step - loss: 0.0219 - out1_loss: 0.0048 - out2_loss: 0.0029 - out3_loss: 0.0032 - out4_loss: 0.0089 - out5_loss: 0.0021 - out1_mean_absolute_error: 0.0570 - out2_mean_absolute_error: 0.0425 - out3_mean_absolute_error: 0.0456 - out4_mean_absolute_error: 0.0714 - out5_mean_absolute_error: 0.0357
# Epoch 9/30
# 247/247 [==============================] - 34s 136ms/step - loss: 0.0209 - out1_loss: 0.0049 - out2_loss: 0.0028 - out3_loss: 0.0027 - out4_loss: 0.0083 - out5_loss: 0.0022 - out1_mean_absolute_error: 0.0570 - out2_mean_absolute_error: 0.0425 - out3_mean_absolute_error: 0.0420 - out4_mean_absolute_error: 0.0692 - out5_mean_absolute_error: 0.0368
# Epoch 10/30
# 247/247 [==============================] - 33s 132ms/step - loss: 0.0202 - out1_loss: 0.0049 - out2_loss: 0.0028 - out3_loss: 0.0024 - out4_loss: 0.0078 - out5_loss: 0.0023 - out1_mean_absolute_error: 0.0570 - out2_mean_absolute_error: 0.0424 - out3_mean_absolute_error: 0.0394 - out4_mean_absolute_error: 0.0672 - out5_mean_absolute_error: 0.0378
# Epoch 11/30
# 247/247 [==============================] - 33s 132ms/step - loss: 0.0195 - out1_loss: 0.0049 - out2_loss: 0.0027 - out3_loss: 0.0021 - out4_loss: 0.0074 - out5_loss: 0.0024 - out1_mean_absolute_error: 0.0567 - out2_mean_absolute_error: 0.0422 - out3_mean_absolute_error: 0.0374 - out4_mean_absolute_error: 0.0654 - out5_mean_absolute_error: 0.0385
# Epoch 12/30
# 247/247 [==============================] - 33s 132ms/step - loss: 0.0189 - out1_loss: 0.0048 - out2_loss: 0.0026 - out3_loss: 0.0020 - out4_loss: 0.0070 - out5_loss: 0.0025 - out1_mean_absolute_error: 0.0563 - out2_mean_absolute_error: 0.0418 - out3_mean_absolute_error: 0.0358 - out4_mean_absolute_error: 0.0639 - out5_mean_absolute_error: 0.0392
# Epoch 13/30
# 247/247 [==============================] - 32s 131ms/step - loss: 0.0183 - out1_loss: 0.0048 - out2_loss: 0.0025 - out3_loss: 0.0018 - out4_loss: 0.0067 - out5_loss: 0.0025 - out1_mean_absolute_error: 0.0556 - out2_mean_absolute_error: 0.0412 - out3_mean_absolute_error: 0.0347 - out4_mean_absolute_error: 0.0625 - out5_mean_absolute_error: 0.0394
# Epoch 14/30
# 247/247 [==============================] - 36s 147ms/step - loss: 0.0175 - out1_loss: 0.0045 - out2_loss: 0.0024 - out3_loss: 0.0017 - out4_loss: 0.0064 - out5_loss: 0.0025 - out1_mean_absolute_error: 0.0544 - out2_mean_absolute_error: 0.0405 - out3_mean_absolute_error: 0.0338 - out4_mean_absolute_error: 0.0614 - out5_mean_absolute_error: 0.0388
# Epoch 15/30
# 247/247 [==============================] - 35s 140ms/step - loss: 0.0169 - out1_loss: 0.0045 - out2_loss: 0.0023 - out3_loss: 0.0017 - out4_loss: 0.0061 - out5_loss: 0.0023 - out1_mean_absolute_error: 0.0537 - out2_mean_absolute_error: 0.0399 - out3_mean_absolute_error: 0.0331 - out4_mean_absolute_error: 0.0603 - out5_mean_absolute_error: 0.0375
# Epoch 16/30
# 247/247 [==============================] - 33s 132ms/step - loss: 0.0164 - out1_loss: 0.0045 - out2_loss: 0.0023 - out3_loss: 0.0016 - out4_loss: 0.0058 - out5_loss: 0.0021 - out1_mean_absolute_error: 0.0525 - out2_mean_absolute_error: 0.0398 - out3_mean_absolute_error: 0.0327 - out4_mean_absolute_error: 0.0596 - out5_mean_absolute_error: 0.0356
# Epoch 17/30
# 247/247 [==============================] - 33s 132ms/step - loss: 0.0156 - out1_loss: 0.0043 - out2_loss: 0.0023 - out3_loss: 0.0016 - out4_loss: 0.0055 - out5_loss: 0.0019 - out1_mean_absolute_error: 0.0524 - out2_mean_absolute_error: 0.0391 - out3_mean_absolute_error: 0.0324 - out4_mean_absolute_error: 0.0586 - out5_mean_absolute_error: 0.0341
# Epoch 18/30
# 247/247 [==============================] - 33s 133ms/step - loss: 0.0154 - out1_loss: 0.0044 - out2_loss: 0.0023 - out3_loss: 0.0015 - out4_loss: 0.0054 - out5_loss: 0.0017 - out1_mean_absolute_error: 0.0510 - out2_mean_absolute_error: 0.0391 - out3_mean_absolute_error: 0.0319 - out4_mean_absolute_error: 0.0581 - out5_mean_absolute_error: 0.0325
# Epoch 19/30
# 247/247 [==============================] - 33s 133ms/step - loss: 0.0145 - out1_loss: 0.0041 - out2_loss: 0.0023 - out3_loss: 0.0015 - out4_loss: 0.0049 - out5_loss: 0.0016 - out1_mean_absolute_error: 0.0509 - out2_mean_absolute_error: 0.0386 - out3_mean_absolute_error: 0.0317 - out4_mean_absolute_error: 0.0562 - out5_mean_absolute_error: 0.0313
# Epoch 20/30
# 247/247 [==============================] - 32s 132ms/step - loss: 0.0146 - out1_loss: 0.0041 - out2_loss: 0.0024 - out3_loss: 0.0015 - out4_loss: 0.0051 - out5_loss: 0.0015 - out1_mean_absolute_error: 0.0498 - out2_mean_absolute_error: 0.0392 - out3_mean_absolute_error: 0.0313 - out4_mean_absolute_error: 0.0568 - out5_mean_absolute_error: 0.0301
# Epoch 21/30
# 247/247 [==============================] - 32s 131ms/step - loss: 0.0130 - out1_loss: 0.0036 - out2_loss: 0.0024 - out3_loss: 0.0014 - out4_loss: 0.0042 - out5_loss: 0.0014 - out1_mean_absolute_error: 0.0486 - out2_mean_absolute_error: 0.0388 - out3_mean_absolute_error: 0.0307 - out4_mean_absolute_error: 0.0531 - out5_mean_absolute_error: 0.0291
# Epoch 22/30
# 247/247 [==============================] - 33s 132ms/step - loss: 0.0138 - out1_loss: 0.0039 - out2_loss: 0.0025 - out3_loss: 0.0014 - out4_loss: 0.0047 - out5_loss: 0.0013 - out1_mean_absolute_error: 0.0481 - out2_mean_absolute_error: 0.0400 - out3_mean_absolute_error: 0.0301 - out4_mean_absolute_error: 0.0549 - out5_mean_absolute_error: 0.0282
# Epoch 23/30
# 247/247 [==============================] - 33s 134ms/step - loss: 0.0120 - out1_loss: 0.0035 - out2_loss: 0.0026 - out3_loss: 0.0013 - out4_loss: 0.0035 - out5_loss: 0.0011 - out1_mean_absolute_error: 0.0470 - out2_mean_absolute_error: 0.0402 - out3_mean_absolute_error: 0.0291 - out4_mean_absolute_error: 0.0493 - out5_mean_absolute_error: 0.0268
# Epoch 24/30
# 247/247 [==============================] - 33s 133ms/step - loss: 0.0138 - out1_loss: 0.0036 - out2_loss: 0.0028 - out3_loss: 0.0012 - out4_loss: 0.0050 - out5_loss: 0.0011 - out1_mean_absolute_error: 0.0462 - out2_mean_absolute_error: 0.0419 - out3_mean_absolute_error: 0.0288 - out4_mean_absolute_error: 0.0555 - out5_mean_absolute_error: 0.0267
# Epoch 25/30
# 247/247 [==============================] - 33s 133ms/step - loss: 0.0129 - out1_loss: 0.0032 - out2_loss: 0.0029 - out3_loss: 0.0012 - out4_loss: 0.0045 - out5_loss: 0.0011 - out1_mean_absolute_error: 0.0446 - out2_mean_absolute_error: 0.0430 - out3_mean_absolute_error: 0.0285 - out4_mean_absolute_error: 0.0528 - out5_mean_absolute_error: 0.0262
# Epoch 26/30
# 247/247 [==============================] - 33s 134ms/step - loss: 0.0114 - out1_loss: 0.0029 - out2_loss: 0.0032 - out3_loss: 0.0011 - out4_loss: 0.0032 - out5_loss: 9.8380e-04 - out1_mean_absolute_error: 0.0417 - out2_mean_absolute_error: 0.0449 - out3_mean_absolute_error: 0.0275 - out4_mean_absolute_error: 0.0465 - out5_mean_absolute_error: 0.0251
# Epoch 27/30
# 247/247 [==============================] - 33s 132ms/step - loss: 0.0110 - out1_loss: 0.0028 - out2_loss: 0.0033 - out3_loss: 0.0011 - out4_loss: 0.0028 - out5_loss: 9.2423e-04 - out1_mean_absolute_error: 0.0410 - out2_mean_absolute_error: 0.0460 - out3_mean_absolute_error: 0.0267 - out4_mean_absolute_error: 0.0448 - out5_mean_absolute_error: 0.0243
# Epoch 28/30
# 247/247 [==============================] - 33s 134ms/step - loss: 0.0103 - out1_loss: 0.0024 - out2_loss: 0.0034 - out3_loss: 9.7652e-04 - out4_loss: 0.0027 - out5_loss: 8.4852e-04 - out1_mean_absolute_error: 0.0380 - out2_mean_absolute_error: 0.0462 - out3_mean_absolute_error: 0.0255 - out4_mean_absolute_error: 0.0436 - out5_mean_absolute_error: 0.0234
# Epoch 29/30
# 247/247 [==============================] - 32s 130ms/step - loss: 0.0100 - out1_loss: 0.0021 - out2_loss: 0.0037 - out3_loss: 9.0284e-04 - out4_loss: 0.0026 - out5_loss: 7.7913e-04 - out1_mean_absolute_error: 0.0358 - out2_mean_absolute_error: 0.0473 - out3_mean_absolute_error: 0.0246 - out4_mean_absolute_error: 0.0426 - out5_mean_absolute_error: 0.0224
# Epoch 30/30
# 247/247 [==============================] - 32s 131ms/step - loss: 0.0094 - out1_loss: 0.0017 - out2_loss: 0.0038 - out3_loss: 8.3252e-04 - out4_loss: 0.0024 - out5_loss: 7.1561e-04 - out1_mean_absolute_error: 0.0330 - out2_mean_absolute_error: 0.0473 - out3_mean_absolute_error: 0.0236 - out4_mean_absolute_error: 0.0410 - out5_mean_absolute_error: 0.0215

# %%
model.evaluate_generator(test_generator, verbose=2)  
o1,o2,o3,o4,o5=model.predict_generator(test_generator)
# Out:
# WARNING:tensorflow:From <ipython-input-24-bd9fd796f97b>:1: Model.evaluate_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.evaluate, which supports generators.
# 1900/1900 - 28s - loss: 0.4401 - out1_loss: 0.0497 - out2_loss: 0.0658 - out3_loss: 0.1520 - out4_loss: 0.0544 - out5_loss: 0.1182 - out1_mean_absolute_error: 0.1842 - out2_mean_absolute_error: 0.2166 - out3_mean_absolute_error: 0.3096 - out4_mean_absolute_error: 0.1947 - out5_mean_absolute_error: 0.2721
# WARNING:tensorflow:From <ipython-input-24-bd9fd796f97b>:2: Model.predict_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.predict, which supports generators.

# %%
testX=np.array(([test_generator[0][0][0,:]]))
testY1=np.array(np.vstack((test_generator[0][1][:,0])))
testY2=np.array(np.vstack((test_generator[0][1][:,1])))
testY3=np.array(np.vstack((test_generator[0][1][:,2])))
testY4=np.array(np.vstack((test_generator[0][1][:,3])))
testY5=np.array(np.vstack((test_generator[0][1][:,4])))

for i in range(1,1899):
    testX=np.vstack((X,[test_generator[i][0][0,:]]))
    testY1=np.vstack((Y1,test_generator[i][1][:,0]))
    testY2=np.vstack((Y2,test_generator[i][1][:,1]))
    testY3=np.vstack((Y3,test_generator[i][1][:,2]))
    testY4=np.vstack((Y4,test_generator[i][1][:,3]))
    testY5=np.vstack((Y5,test_generator[i][1][:,4]))

# %%
df_pred=pd.concat([pd.DataFrame(o1), pd.DataFrame(o2),pd.DataFrame(o3),pd.DataFrame(o4),pd.DataFrame(o5)],axis=1)

# %%
df_pred
# Out:
#              0         0         0         0         0
# 0     0.784610  0.220801  0.509578  0.425855  0.577658
# 1     0.784497  0.222681  0.507144  0.425756  0.575254
# 2     0.784384  0.224564  0.504903  0.425655  0.572828
# 3     0.784274  0.226446  0.502853  0.425555  0.570384
# 4     0.784167  0.228325  0.500992  0.425458  0.567925
# ...        ...       ...       ...       ...       ...
# 1895  0.677518  0.497432  0.048567  0.577324  0.197848
# 1896  0.678482  0.497631  0.050324  0.577197  0.204351
# 1897  0.679465  0.497857  0.052158  0.577071  0.211143
# 1898  0.680470  0.498111  0.054067  0.576947  0.218221
# 1899  0.681497  0.498395  0.056045  0.576826  0.225581
#
# [1900 rows x 5 columns]

# %%
rev_trans=scaler.inverse_transform(df_pred)
rev_trans
# Out:
# array([[ 78.45318   , -39.259487  ,   0.29097548, -54.144     ,
#           2.5796494 ],
#        [ 78.44181   , -39.143116  ,   0.22415265, -54.153896  ,
#           2.499287  ],
#        [ 78.43058   , -39.026596  ,   0.16263413, -54.16396   ,
#           2.418197  ],
#        ...,
#        [ 67.93971   , -22.111177  , -12.2650795 , -39.056026  ,
#          -9.672906  ],
#        [ 68.040146  , -22.095428  , -12.212682  , -39.068394  ,
#          -9.4362755 ],
#        [ 68.14286   , -22.077883  , -12.15838   , -39.080475  ,
#          -9.190242  ]], dtype=float32)

# %%
plt.figure()
plt.xlabel('Time', fontsize=12)
plt.ylabel('$\\theta1$ Position', fontsize=12)
plt.title('Simulated Trajectory of Double Pendulum time versus $\\theta1$ for 1.9s')
plt.plot(data[:,0][8100:10000], rev_trans[:,1],label='Predicated First Pendulum (X1,Y1)' ,color="c")
plt.plot(data[:,0][8100:10000],data[:,1][8100:10000],label='Simulated First Pendulum (X1,Y1)' ,color="red")
plt.legend()

# %%
plt.figure()
plt.xlabel('Time', fontsize=12)
plt.ylabel('$\\theta2$ Position', fontsize=12)
plt.title('Simulated Trajectory of Double Pendulum time versus $\\theta2$ for 1.9s')
plt.plot(data[:,0][8100:10000], rev_trans[:,3],label='Predicated First Pendulum (X1,Y1)' ,color="c")
plt.plot(data[:,0][8100:10000],data[:,3][8100:10000],color="red")
plt.legend()

# %%
plt.figure(figsize=(6,6))
plt.xlabel('X-axis Position', fontsize=12)
plt.ylabel('Y-axis Position', fontsize=12)
plt.title('Simulated Trajectory of Double Pendulum (X1,Y1) for 1.9s')
plt.plot(L1*sin(rev_trans[:,1]), -L1*cos(rev_trans[:,1]),label='Predicated First Pendulum (X1,Y1)' ,color="c")
plt.plot(L1*sin(data[:,1][8100:10000]), -L1*cos(data[:,1][8100:10000]),label='Simulated First Pendulum (X1,Y1)' ,color="RED")
plt.legend()

# %%
plt.figure(figsize=(8,6))
plt.xlabel('X-axis Position', fontsize=12)
plt.ylabel('Y-axis Position', fontsize=12)
plt.title('Simulated Trajectory of Double Pendulum (X2,Y2) for 1.9s')
plt.plot(L2*sin(data[:,3][8100:10000])+L1*sin(data[:,1][8100:10000]), -L2*cos(data[:,3][8100:10000])-L2*cos(data[:,1][8100:10000]),label='Simulated Second Pendulum (X2,Y2)' ,color="RED")
plt.plot(L2*sin(rev_trans[:,3])+L1*sin(rev_trans[:,1]), -L2*cos(rev_trans[:,3])-L2*cos(rev_trans[:,1]),label='Predicated Second Pendulum (X2,Y2)' ,color="c")
plt.legend()

# %%
plt.figure()
plt.xlabel('Time', fontsize=12)
plt.ylabel('Angular Velocity $\\dot{\\theta1}$', fontsize=12)
plt.title('Simulated versus Predicted angular velocity of Double Pendulum (time versus $\\dot{\\theta1}$) for 1.9s')
plt.plot(data[:,0][8100:10000], rev_trans[:,2],label='Predicated First Pendulum (t,$\\dot{\\theta1}$)' ,color="c")
plt.plot(data[:,0][8100:10000],data[:,2][8100:10000],label='Simulated First Pendulum (t,$\\dot{\\theta1}$)' ,color="red")
plt.legend()

# %%
plt.figure()
plt.xlabel('Time', fontsize=12)
plt.ylabel('Angular Velocity $\\dot{\\theta2}$', fontsize=12)
plt.title('Simulated versus Predicted angular velocity of Double Pendulum (time versus $\\dot{\\theta2}$) for 1.9s')
plt.plot(data[:,0][8100:10000], rev_trans[:,2],label='Predicated First Pendulum (t,$\\dot{\\theta2}$)' ,color="c")
plt.plot(data[:,0][8100:10000],data[:,2][8100:10000],label='Simulated First Pendulum (t,$\\dot{\\theta2}$)' ,color="red")
plt.legend()
